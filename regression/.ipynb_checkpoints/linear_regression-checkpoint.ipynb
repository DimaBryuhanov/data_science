# %% [markdown]
# ### Usecases
# 1. sales forecasting
# 2. Supply cost forecasting
# 3. Resource Consumption forecasting
# 4. Telecom services lifecycle forecasting
#
# ### Assumptions:
# 1. All variables are numerical
# 2. No categorical variables
# 3. variables are continuous
# 4. Data is free from missing data & outliers
# 5. There's a linear relationship between the predictor & the predictant
# 6. All predictor are independant of each other
# 7. Residuals (prediction errors) are normaly distributed
#
# # Simple Linear Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

from pylab import rcParams

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import scale

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 10, 8

# %% [markdown]
# ### Generating mock data:

# %%
rooms = 2 * np.random.rand(100, 1) + 3
price = 265 + 6 * rooms + abs(np.random.rand(100, 1))

# %%
plt.plot(rooms, price, 'r^')
plt.xlabel("# rooms 2019 average")
plt.ylabel("2019 average home price (* $1000)")
plt.show()

# %%
X = rooms
y = price

lin_reg = LinearRegression()
lin_reg.fit(X, y)
print(lin_reg.intercept_, lin_reg.coef_)
# Out:
# [265.17941302] [[6.08132633]]

# %% [markdown]
# *Simple Algebra*
#
# - y = mx + b
# - b = intercept = 265.17
#
# *Estimated coefficients*
# lin_reg.coef_ = 6.08

# %%
print(lin_reg.score(X, y))
# Out:
# 0.9922480315405409

# %% [markdown]
# # Multiple linear regression

# %%
import seaborn as sb
sb.set_style('whitegrid')
from collections import Counter

# %%
address = '../Data/enrollment_forecast.csv'
enroll = pd.read_csv(address)
enroll.columns = ['year', 'roll', 'unem', 'hgrad', 'inc']
enroll.head()
# Out:
#    year  roll  unem  hgrad   inc
# 0     1  5501   8.1   9552  1923
# 1     2  5945   7.0   9680  1961
# 2     3  6629   7.3   9731  1979
# 3     4  7556   7.5  11666  2030
# 4     5  8716   7.0  14675  2112

# %%
sb.pairplot(enroll)

# %%
print(enroll.corr())
# Out:
#            year      roll      unem     hgrad       inc
# year   1.000000  0.900934  0.378305  0.670300  0.944287
# roll   0.900934  1.000000  0.391344  0.890294  0.949876
# unem   0.378305  0.391344  1.000000  0.177376  0.282310
# hgrad  0.670300  0.890294  0.177376  1.000000  0.820089
# inc    0.944287  0.949876  0.282310  0.820089  1.000000

# %%
enroll_data_names = ['unem', 'hgrad']
enroll_data = enroll[enroll_data_names].values
enroll_targets = enroll[['roll']].values
